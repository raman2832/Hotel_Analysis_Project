# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:\\Users\\my\\Downloads\\archive (2)\\hotel_booking.csv')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %% [markdown]
# * OUT OF 36 COLUMNS LAST 4 COLUMNS ARE OF PERSONAL DETAILS.

# %% [markdown]
# * WE DO NOT NEED PERSONAL DETAILS IN THE ANALYSIS THEREFORE DROPPING IT

# %%
df.drop(['name', 'email', 'phone-number', 'credit_card'], axis = 1 , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.describe(include = 'all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# *****UNIVARIATE ANALYSIS*****
# ---------------------------------------------------------------------------
# * THERE ARE TOTAL OF 119390 RECORDS OF ONLY 2 HOTELS IN THE GIVEN DATASET viz CITY HOTEL & RESORT HOTEL
# * MOST BOOKED HOTEL -----> "CITY HOTEL"
# * HOTELS ARE BOOKED ALL OVER THE YEAR
# * "AUGUST" IS THE PEAK MONTHS WITH RECORD 13877 BOOKINGS
# * AVERAGE OF ADR IS ABOUT 101.82
# * MIN ADR = -6.3 & MAX ADR = 5400 (OUTLYER)
# * ONCE WAITING LIST TOUCHED RECORD OF "391 DAYS OF WAITING"

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# 1. There are too much record are missing in the 'Agent' and 'Company' columns so we goona remove it.
# 2. Removing records from 'Country' and 'Children' columns as values are missing and also count of such records are less.
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %%
df.drop(['company','agent'], axis =1 , inplace = True)
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df['adr'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1. There is a only one value in 'adr' that is to high(outlyer) can affect the analysis so we will remove it.

# %%
df = df[df['adr']<5000]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# DATA ANALYSIS AND VISUALISATION
# ======================================

# %%
cancelled_perc = df['is_canceled'].value_counts()
print(cancelled_perc)
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %%
print(cancelled_perc)
plt.figure(figsize = (6,4))
plt.title('TOTAL RESERVATION STATUS', fontsize = 20 , color = 'blue')
plt.bar(['CHECK-IN', 'CANCELED'],df['is_canceled'].value_counts(),width= 0.7)
plt.xlabel('STATUS', fontsize = 15, color = 'blue')
plt.ylabel('NUMBER OF CUSTOMERS', fontsize = 15, color = 'blue')
plt.show()
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %% [markdown]
# =================
# Interpretation from graph
# ================
#
#
# 1. Around 37% of booking got canceled which is nearly 44000

# %%
hotels_perc = df['hotel'].value_counts()
hotels_perc
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
plt.figure(figsize = (6,4))
#graph_1 = sns.countplot(x = 'hotel', hue = 'hotel' , data = df, palette  ='Greens')
plt.bar(['CITY HOTEL','RESORT HOTEL'],df['hotel'].value_counts(),color = 'green', width = 0.6)
plt.title('BOOKING STATUS', fontsize = 20, color = 'green')
plt.xlabel('HOTEL', fontsize = 15, color = 'green')
plt.ylabel('NUMBER OF BOOKINGS', fontsize = 15, color = 'green')

plt.show()

# %%
plt.figure(figsize = (10,5))
graph_1 = sns.countplot(x = 'hotel', hue = 'is_canceled' , data = df, palette  ='Reds')
plt.title('HOTELS RESERVATION STATUS', fontsize = 20, color = 'Brown')
plt.xlabel('HOTEL', fontsize = 15, color = 'Brown')
plt.ylabel('NUMBER OF RESERVATIONS', fontsize = 15, color = 'Brown')
plt.legend(['CHECK-IN' , 'CANCELED'])
plt.show()

# %%
resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# 0    0.722366
# 1    0.277634
# Name: is_canceled, dtype: float64

# %%
city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# 0    0.58273
# 1    0.41727
# Name: is_canceled, dtype: float64

# %% [markdown]
# ---------------------------------------------------------
# 1. On comparision City Hotel Cancelation Rate is way Higher than Resort Hotel

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize = (20,8))
plt.title('Average rate in city and resort hotel', fontsize = 20, color = 'orange')
plt.plot(resort_hotel.index, resort_hotel['adr'], label = 'Resort Hotel')
plt.plot(city_hotel.index, city_hotel['adr'], label = 'City Hotel')
plt.legend()
plt.show()

# %%
df['month']  = df['reservation_status_date'].dt.month
plt.figure(figsize = (16,8))
graph_2 = sns.countplot(x= 'month', hue = 'is_canceled', data =df, palette = 'Greys')
plt.xlabel('MONTH------>', fontsize = 15, color = 'grey')
plt.ylabel('NUMBER OF RESERVATION', fontsize = 15, color = 'grey')
plt.title('RESERVATION STATUS PER MONTH', fontsize = 20, color = 'grey')
plt.legend(['CHECK-IN' , 'CANCELED'])
plt.show()

# %%
plt.figure(figsize = (16,8))
graph_3 = sns.barplot(x='month',y='adr', data =df[df['is_canceled']==1].groupby('month')[['adr']].sum().reset_index())
plt.xlabel('MONTHS', fontsize = 15, color = 'purple')
plt.ylabel('ADR', fontsize = 15, color = 'purple')
plt.title('AVERAGE DAILY RATES PER MONTH', fontsize = 20, color = 'purple')
#plt.legend(['not canceled' , 'canceled'])
plt.show()

# %%
# For top 10 countries
reservation_cancelled = df[df['is_canceled']==1]
top_10_con = reservation_cancelled['country'].value_counts()[:10]
top_10_con
# Out:
# PRT    27519
# GBR     2453
# ESP     2177
# FRA     1934
# ITA     1333
# DEU     1218
# IRL      832
# BRA      830
# USA      501
# BEL      474
# Name: country, dtype: int64

# %%
plt.figure(figsize = (12,6))
plt.title('RESERVATION CANCELED IN TOP-10 COUNTRIES', fontsize = 15, color = 'aqua')
graph_4 = plt.pie(top_10_con, autopct ='%.2f', labels = top_10_con.index)


plt.show()

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts(normalize = True)
# Out:
# Online TA        0.473046
# Offline TA/TO    0.202856
# Groups           0.165935
# Direct           0.105587
# Corporate        0.044350
# Complementary    0.006223
# Aviation         0.001985
# Undefined        0.000017
# Name: market_segment, dtype: float64

# %%
canceled_data = df[df['is_canceled']==1]
canceled_data['market_segment'].value_counts(normalize = True)
# Out:
# Online TA        0.468954
# Groups           0.273539
# Offline TA/TO    0.187930
# Direct           0.043732
# Corporate        0.022431
# Complementary    0.002193
# Aviation         0.001176
# Undefined        0.000045
# Name: market_segment, dtype: float64

# %%
not_canceled_data = df[df['is_canceled']==0]
not_canceled_data['market_segment'].value_counts(normalize = True)
# Out:
# Online TA        0.475454
# Offline TA/TO    0.211638
# Direct           0.141979
# Groups           0.102626
# Corporate        0.057247
# Complementary    0.008594
# Aviation         0.002461
# Name: market_segment, dtype: float64

# %%
canceled_df_adr = canceled_data.groupby('reservation_status_date')[['adr']].mean()
canceled_df_adr.reset_index(inplace = True)
canceled_df_adr.sort_values('reservation_status_date',inplace = True)

not_canceled_df_adr = not_canceled_data.groupby('reservation_status_date')[['adr']].mean()
not_canceled_df_adr.reset_index(inplace = True)
not_canceled_df_adr.sort_values('reservation_status_date',inplace = True)

plt.figure(figsize = (20,6))
plt.plot(not_canceled_df_adr['reservation_status_date'],not_canceled_df_adr['adr'], label  = 'CHECK-IN')
plt.plot(canceled_df_adr['reservation_status_date'],canceled_df_adr['adr'], label  = 'CANCELED')

plt.title('RESERVATION STATUS AS PER ADR',fontsize = 20, color = 'orange')
plt.legend(fontsize = 15)
plt.show()

# %%
not_canceled_df_adr = not_canceled_df_adr[(not_canceled_df_adr['reservation_status_date']>'2016') & (not_canceled_df_adr['reservation_status_date'] <'2017 -09')]
canceled_df_adr = canceled_df_adr[(canceled_df_adr['reservation_status_date']>'2016') & (canceled_df_adr['reservation_status_date'] <'2017 -09')]

# %%
plt.figure(figsize = (20,6))
plt.plot(not_canceled_df_adr['reservation_status_date'],not_canceled_df_adr['adr'], label  = 'CHECK-IN')
plt.plot(canceled_df_adr['reservation_status_date'],canceled_df_adr['adr'], label  = 'CANCELED')

plt.title('RESERVATION STATUS AS PER ADR (2016 TO 09-2017)',fontsize = 20, color = 'orange')
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# THE END
# ===========
# THANK YOU
# ===================
